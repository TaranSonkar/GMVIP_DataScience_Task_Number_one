# %%
#load dataset
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.datasets import load_iris

# %%
Iris=load_iris()

# %%
#Iris

# %%
Iris.data.shape
# Out:
# (150, 4)

# %%
Iris.target.shape
# Out:
# (150,)

# %%
Iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
Iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
print(Iris.DESCR)
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, predictive attributes and the class
#     :Attribute Information:
#         - sepal length in cm
#         - sepal width in cm
#         - petal length in cm
#         - petal width in cm
#         - class:
#                 - Iris-Setosa
#                 - Iris-Versicolour
#                 - Iris-Virginica
#
#     :Summary Statistics:
#
#     ============== ==== ==== ======= ===== ====================
#                     Min  Max   Mean    SD   Class Correlation
#     ============== ==== ==== ======= ===== ====================
#     sepal length:   4.3  7.9   5.84   0.83    0.7826
#     sepal width:    2.0  4.4   3.05   0.43   -0.4194
#     petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
#     petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
# ...

# %%
#convert data into pandas dataframe

# %%
#iris = load_iris()
#iris=pd.read_csv('/content/sample_data/iris.csv')
df=pd.DataFrame(Iris.data,columns=Iris.feature_names)

# %%
#preview data
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
df.tail()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8

# %%
#include the target
df['target']=Iris.target

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df.dtypes
# Out:
# sepal length (cm)    float64
# sepal width (cm)     float64
# petal length (cm)    float64
# petal width (cm)     float64
# target                 int64
# dtype: object

# %%
#Description of Data
#print(iris.describe())
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)      target
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
# ...

# %%
#Flower distribution

print(df.groupby('target').size())
# Out:
# target
# 0    50
# 1    50
# 2    50
# dtype: int64

# %%
#Data Shape
print(df.shape)
# Out:
# (150, 5)

# %%
#Data Visualization
#BoxPlot and whisker plot
df.plot(kind='box',subplots=True,layout=(3,2),figsize=(8,12))
# Out:
# sepal length (cm)       Axes(0.125,0.653529;0.352273x0.226471)
# sepal width (cm)     Axes(0.547727,0.653529;0.352273x0.226471)
# petal length (cm)       Axes(0.125,0.381765;0.352273x0.226471)
# petal width (cm)     Axes(0.547727,0.381765;0.352273x0.226471)
# target                      Axes(0.125,0.11;0.352273x0.226471)
# dtype: object

# %%
df.hist(figsize=(12,12))
plt.show()

# %%
df.corr()
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.117570           0.871754
# sepal width (cm)           -0.117570          1.000000          -0.428440
# petal length (cm)           0.871754         -0.428440           1.000000
# petal width (cm)            0.817941         -0.366126           0.962865
# target                      0.782561         -0.426658           0.949035
#
#                    petal width (cm)    target
# sepal length (cm)          0.817941  0.782561
# sepal width (cm)          -0.366126 -0.426658
# petal length (cm)          0.962865  0.949035
# petal width (cm)           1.000000  0.956547
# target                     0.956547  1.000000

# %%
sns.heatmap(df.corr(),annot=True,cmap='Wistia')
# Out:
# <Axes: >

# %%
sns.pairplot(df)

# %%
sns.catplot(x='petal length (cm)', y='petal width (cm)', palette='coolwarm', hue='target', data=df)

# %%
sns.pairplot(df, hue='target', size=3, diag_kind="kde")
sns.pairplot(df,hue='target')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# A list is given[34,87,892,920,974,893]
# mean max min
a=np.array([34,87,892,920,974,893])
a
print('min',min(a))
print('max',max(a))
print('mean',np.mean(a))
# Out:
# min 34
# max 974
# mean 633.3333333333334

# %%
#pandas
pd.Series(a)
print('min',min(a))
print('max',max(a))
df=pd.DataFrame(a)
print(df.mean(axis=0))
df
# Out:
# min 34
# max 974
# 0    633.333333
# dtype: float64
#      0
# 0   34
# 1   87
# 2  892
# 3  920
# 4  974
# 5  893

# %%
# A list is given [9,56,826,784]
#multiply 5 without using loop
a=np.array([9,56,826,784])
a*5
# Out:
# array([  45,  280, 4130, 3920])

# %%
import numpy as np
x = np.random.randn(1000)
print("Average of the array elements:")
mean = x.mean()
print(mean)
print("Standard deviation of the array elements:")
std = x.std()
print(std)
print("Variance of the array elements:")
var = x.var()
print(var)
# Out:
# Average of the array elements:
# 0.020316461447171058
# Standard deviation of the array elements:
# 1.0132145990381773
# Variance of the array elements:
# 1.0266038237040944

# %%
#
import numpy as np
x = np.random.randint(low=10, high=30, size=6)
print(x)
# Out:
# [19 18 27 16 14 11]

# %%
import numpy as np
x = np.random.random((5,5))
print("Original Array:")
print(x)
xmin, xmax = x.min(), x.max()
print("Minimum and Maximum Values:")
print(xmin, xmax)
# Out:
# Original Array:
# [[0.63207796 0.05329178 0.63752171 0.36985113 0.1175711 ]
#  [0.10740459 0.30333156 0.46685816 0.28371936 0.8426699 ]
#  [0.70897264 0.46323872 0.7533324  0.82186812 0.13365389]
#  [0.72224739 0.36252201 0.63510224 0.08968352 0.78155646]
#  [0.8267754  0.18610046 0.79618528 0.18034622 0.08056149]]
# Minimum and Maximum Values:
# 0.05329178416163083 0.8426698980102276

# %%
import pandas as pd
